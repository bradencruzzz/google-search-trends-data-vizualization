# %% [markdown]
# <a href="https://colab.research.google.com/github/bradencruzzz/google-search-trends-data-vizualization/blob/main/google_search_trends_data_vizualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %% [markdown]
# Google Trends gives us an estimate of search volume. Let's explore if search popularity relates to other kinds of data. Perhaps there are patterns in Google's search volume and the price of Bitcoin or a hot stock like Tesla. Perhaps search volume for the term "Unemployment Benefits" can tell us something about the actual unemployment rate?
#
# Data Sources: <br>
# <ul>
# <li> <a href="https://fred.stlouisfed.org/series/UNRATE/">Unemployment Rate from FRED</a></li>
# <li> <a href="https://trends.google.com/trends/explore">Google Trends</a> </li>
# <li> <a href="https://finance.yahoo.com/quote/TSLA/history?p=TSLA">Yahoo Finance for Tesla Stock Price</a> </li>
# <li> <a href="https://finance.yahoo.com/quote/BTC-USD/history?p=BTC-USD">Yahoo Finance for Bitcoin Stock Price</a> </li>
# </ul>

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import FuncFormatter

# %% [markdown]
# # Read the Data
#
# Download and add the .csv files to the same folder as your notebook.

# %%
df_tesla = pd.read_csv('Google Trends Data/TESLA Search Trend vs Price.csv')

df_btc_search = pd.read_csv('Google Trends Data/Bitcoin Search Trend.csv')
df_btc_price = pd.read_csv('Google Trends Data/Daily Bitcoin Price.csv')

df_unemployment = pd.read_csv('Google Trends Data/UE Benefits Search vs UE Rate 2004-19.csv')

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ### Tesla

# %% [markdown]
# **Challenge**: <br>
# <ul>
# <li>What are the shapes of the dataframes? </li>
# <li>How many rows and columns? </li>
# <li>What are the column names? </li>
# <li>Complete the f-string to show the largest/smallest number in the search data column</li>
# <li>Try the <code>.describe()</code> function to see some useful descriptive statistics</li>
# <li>What is the periodicity of the time series data (daily, weekly, monthly)? </li>
# <li>What does a value of 100 in the Google Trend search popularity actually mean?</li>
# </ul>

# %%
df_tesla.shape
# Out:
# (124, 3)

# %%
df_tesla.head()
# Out:
#         MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 0  2010-06-01                3           4.766
# 1  2010-07-01                3           3.988
# 2  2010-08-01                2           3.896
# 3  2010-09-01                2           4.082
# 4  2010-10-01                2           4.368

# %%
large_val = df_tesla['TSLA_WEB_SEARCH'].describe()['max']
small_val = df_tesla['TSLA_WEB_SEARCH'].describe()['min']

# %%
print(f'Largest value for Tesla in Web Search: {large_val}')
print(f'Smallest value for Tesla in Web Search: {small_val} ')
# Out:
# Largest value for Tesla in Web Search: 31.0
# Smallest value for Tesla in Web Search: 2.0

# %% [markdown]
# Periodicity: Month

# %% [markdown]
# ### Unemployment Data

# %%
df_unemployment.shape
# Out:
# (181, 3)

# %%
df_unemployment.head()
# Out:
#      MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0  2004-01                      34     5.7
# 1  2004-02                      33     5.6
# 2  2004-03                      25     5.8
# 3  2004-04                      29     5.6
# 4  2004-05                      23     5.6

# %%
print(f'Largest value for "Unemployemnt Benefits" {df_unemployment["UE_BENEFITS_WEB_SEARCH"].describe()["max"]}')
print(f'Smallest value for "Unemployemnt Benefits" {df_unemployment["UE_BENEFITS_WEB_SEARCH"].describe()["min"]}')
# Out:
# Largest value for "Unemployemnt Benefits" 100.0
# Smallest value for "Unemployemnt Benefits" 14.0

# %% [markdown]
# ### Bitcoin

# %%
df_btc_search.shape
# Out:
# (73, 2)

# %%
df_btc_search.head()
# Out:
#      MONTH  BTC_NEWS_SEARCH
# 0  2014-09                5
# 1  2014-10                4
# 2  2014-11                4
# 3  2014-12                4
# 4  2015-01                5

# %%
print(f"largest BTC News Search: {df_btc_search['BTC_NEWS_SEARCH'].describe()['max']}")
# Out:
# largest BTC News Search: 100.0

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Check for Missing Values

# %% [markdown]
# **Challenge**: Are there any missing values in any of the dataframes? If so, which row/rows have missing values? How many missing values are there?

# %%
print(f'Missing values for Tesla?: {df_tesla.isna().values.any()}')
print(f'Missing values for U/E?: {df_unemployment.isna().values.any()} ')
print(f'Missing values for BTC Search?: {df_btc_search.isna().values.any()} ')
print(f'Missing values for BTC Price?: {df_btc_price.isna().values.any()} ')
# Out:
# Missing values for Tesla?: False
# Missing values for U/E?: False
# Missing values for BTC Search?: False
# Missing values for BTC Price?: True
# 2

# %%
print(f'Number of missing values: {df_btc_price.isna().values.sum()} ')
df_btc_price[df_btc_price.CLOSE.isna()]
# Out:
# Number of missing values: 2
#             DATE  CLOSE  VOLUME
# 2148  2020-08-04    NaN     NaN

# %% [markdown]
# **Challenge**: Remove any missing values that you found.

# %%
df_btc_price.dropna(inplace=True)
# Out:
# /tmp/ipython-input-70-3682256282.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_btc_price.dropna(inplace=True)

# %% [markdown]
# ### Convert Strings to DateTime Objects

# %% [markdown]
# **Challenge**: Check the data type of the entries in the DataFrame MONTH or DATE columns. Convert any strings in to Datetime objects. Do this for all 4 DataFrames. Double check if your type conversion was successful.

# %%
df_btc_price['DATE'] = pd.to_datetime(df_btc_price['DATE'])
print(df_btc_price.dtypes)
# Out:
# DATE      datetime64[ns]
# CLOSE            float64
# VOLUME           float64
# dtype: object

# %%
df_btc_search['MONTH'] = pd.to_datetime(df_btc_search['MONTH'])
print(df_btc_search.dtypes)
# Out:
# MONTH              datetime64[ns]
# BTC_NEWS_SEARCH             int64
# dtype: object

# %%
df_tesla['MONTH'] = pd.to_datetime(df_tesla['MONTH'])
print(df_tesla.dtypes)
# Out:
# MONTH              datetime64[ns]
# TSLA_WEB_SEARCH             int64
# TSLA_USD_CLOSE            float64
# dtype: object

# %%
df_unemployment['MONTH'] = pd.to_datetime(df_unemployment['MONTH'])
print(df_unemployment.dtypes)
print(type(df_unemployment.MONTH[0]))
# Out:
# MONTH                     datetime64[ns]
# UE_BENEFITS_WEB_SEARCH             int64
# UNRATE                           float64
# dtype: object
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %% [markdown]
# ### Converting from Daily to Monthly Data
#
# [Pandas .resample() documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.resample.html) <br>

# %%
df_btc_price.head()
# Out:
#         DATE       CLOSE      VOLUME
# 0 2014-09-17  457.334015  21056800.0
# 1 2014-09-18  424.440002  34483200.0
# 2 2014-09-19  394.795990  37919700.0
# 3 2014-09-20  408.903992  36863600.0
# 4 2014-09-21  398.821014  26580100.0

# %%
df_btc_search.head()
# Out:
#        MONTH  BTC_NEWS_SEARCH
# 0 2014-09-01                5
# 1 2014-10-01                4
# 2 2014-11-01                4
# 3 2014-12-01                4
# 4 2015-01-01                5

# %%
df_btc_monthly = df_btc_price.resample('M', on='DATE').last()
df_btc_monthly.head()
# Out:
# /tmp/ipython-input-139-273777132.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_btc_monthly = df_btc_price.resample('M', on='DATE').last()
#                  CLOSE      VOLUME
# DATE
# 2014-09-30  386.944000  34707300.0
# 2014-10-31  338.321014  12545400.0
# 2014-11-30  378.046997   9194440.0
# 2014-12-31  320.192993  13942900.0
# 2015-01-31  217.464005  23348200.0

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# ### Notebook Formatting & Style Helpers

# %%
# Create locators for ticks on the time axis
years = mdates.YearLocator()
months = mdates.MonthLocator()
years_fmt = mdates.DateFormatter('%Y')

# %% [markdown]
# ### Tesla Stock Price v.s. Search Volume

# %% [markdown]
# **Challenge:** Plot the Tesla stock price against the Tesla search volume using a line chart and two different axes. Label one axis 'TSLA Stock Price' and the other 'Search Trend'.

# %% [markdown]
# **Challenge**: Make the chart larger and easier to read.
# 1. Increase the figure size (e.g., to 14 by 8).
# 2. Increase the font sizes for the labels and the ticks on the x-axis to 14.
# 3. Rotate the text on the x-axis by 45 degrees.
# 4. Make the lines on the chart thicker.
# 5. Add a title that reads 'Tesla Web Search vs Price'
# 6. Keep the chart looking sharp by changing the dots-per-inch or [DPI value](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.figure.html).
# 7. Set minimum and maximum values for the y and x axis. Hint: check out methods like [set_xlim()](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.axes.Axes.set_xlim.html).
# 8. Finally use [plt.show()](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.show.html) to display the chart below the cell instead of relying on the automatic notebook output.

# %%
plt.figure(figsize=(14, 8), dpi=120)
plt.title('Tesla Web Search vs Price', fontsize=18)

ax1 = plt.gca()
ax2 = ax1.twinx()

# Plotting both lines
ax1.plot(df_tesla['MONTH'], df_tesla['TSLA_USD_CLOSE'], label='TSLA Stock Price', color='r', linewidth=2)
ax2.plot(df_tesla['MONTH'], df_tesla['TSLA_WEB_SEARCH'], label='Search Trend', color='b', linewidth=2)

# Labeling axes
ax1.set_xlabel('Date', fontsize=14)
ax1.set_ylabel('TSLA Stock Price', color='r', fontsize=14)
ax2.set_ylabel('Search Trend', color='b', fontsize=14)

# Tick formatting
ax1.tick_params(axis='y', labelcolor='r', labelsize=14)
ax2.tick_params(axis='y', labelcolor='b', labelsize=14)
ax1.tick_params(axis='x', labelsize=14)

# Date formatting
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

# Show both legends properly
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Bitcoin (BTC) Price v.s. Search Volume

# %% [markdown]
# **Challenge**: Create the same chart for the Bitcoin Prices vs. Search volumes. <br>
# 1. Modify the chart title to read 'Bitcoin News Search vs Resampled Price' <br>
# 2. Change the y-axis label to 'BTC Price' <br>
# 3. Change the y- and x-axis limits to improve the appearance <br>
# 4. Investigate the [linestyles](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.plot.html ) to make the BTC price a dashed line <br>
# 5. Investigate the [marker types](https://matplotlib.org/3.2.1/api/markers_api.html) to make the search datapoints little circles <br>
# 6. Were big increases in searches for Bitcoin accompanied by big increases in the price?

# %%
df_btc_search
# Out:
#         MONTH  BTC_NEWS_SEARCH
# 0  2014-09-01                5
# 1  2014-10-01                4
# 2  2014-11-01                4
# 3  2014-12-01                4
# 4  2015-01-01                5
# ..        ...              ...
# 68 2020-05-01               22
# 69 2020-06-01               13
# 70 2020-07-01               14
# 71 2020-08-01               16
# 72 2020-09-01               13
#
# [73 rows x 2 columns]

# %%
df_btc_monthly.head()
# Out:
#                  CLOSE      VOLUME
# DATE
# 2014-09-30  386.944000  34707300.0
# 2014-10-31  338.321014  12545400.0
# 2014-11-30  378.046997   9194440.0
# 2014-12-31  320.192993  13942900.0
# 2015-01-31  217.464005  23348200.0

# %%
plt.figure(figsize=(14, 8), dpi=120)
plt.title('Bitcoin News Search vs Resampled Price', fontsize=18)

ax1 = plt.gca()
ax2 = ax1.twinx()


# Labeling axes
ax1.set_xlabel('Date', fontsize=14)
ax1.set_ylabel('BTC CLOSING PRICE', color='r', fontsize=14)
ax2.set_ylabel('BTC Search Trend', color='b', fontsize=14)

# Tick formatting
ax1.tick_params(axis='y', labelcolor='r', labelsize=14)
ax2.tick_params(axis='y', labelcolor='b', labelsize=14)
ax1.tick_params(axis='x', labelsize=14)

# Date formatting
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

ax1.set_ylim(bottom=0, top=15000)
ax1.set_xlim([df_btc_monthly.index.min(), df_btc_monthly.index.max()])

# Show both legends properly
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Plotting both lines
ax1.plot(df_btc_monthly.index, df_btc_monthly['CLOSE'], label='BTC Price', color='r', linewidth=2, linestyle='--')
ax2.plot(df_btc_monthly.index, df_btc_search['BTC_NEWS_SEARCH'], label='Search Trend', color='b', linewidth=2, marker='o')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-138-2339958763.py:27: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend(loc='upper left')
# /tmp/ipython-input-138-2339958763.py:28: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax2.legend(loc='upper right')

# %% [markdown]
# ### Unemployement Benefits Search vs. Actual Unemployment in the U.S.

# %% [markdown]
# **Challenge** Plot the search for "unemployment benefits" against the unemployment rate.
# 1. Change the title to: Monthly Search of "Unemployment Benefits" in the U.S. vs the U/E Rate <br>
# 2. Change the y-axis label to: FRED U/E Rate <br>
# 3. Change the axis limits <br>
# 4. Add a grey [grid](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.grid.html) to the chart to better see the years and the U/E rate values. Use dashes for the line style<br>
# 5. Can you discern any seasonality in the searches? Is there a pattern?

# %%
df_unemployment.head()
# Out:
#        MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0 2004-01-01                      34     5.7
# 1 2004-02-01                      33     5.6
# 2 2004-03-01                      25     5.8
# 3 2004-04-01                      29     5.6
# 4 2004-05-01                      23     5.6

# %%
plt.figure(figsize=(14, 8), dpi=120)
plt.title('Unemployment Benefits in the U.S. vs the U/E Rate', fontsize=18)

ax1 = plt.gca()
ax2 = ax1.twinx()


# Labeling axes
ax1.set_xlabel('Date', fontsize=14)
ax1.set_ylabel('FRED U/E RATE', color='r', fontsize=14)
ax2.set_ylabel('SEARCH TREND', color='b', fontsize=14)

# Tick formatting
ax1.tick_params(axis='y', labelcolor='r', labelsize=14)
ax2.tick_params(axis='y', labelcolor='b', labelsize=14)
ax1.tick_params(axis='x', labelsize=14)

# Date formatting
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

ax1.set_ylim(bottom=3, top=10.5)
ax1.set_xlim([df_unemployment['MONTH'].min(), df_unemployment['MONTH'].max()])

ax1.grid(color='grey', linestyle='--')

# Plotting both lines
ax1.plot(df_unemployment['MONTH'], df_unemployment['UNRATE'], label='FRED U/E RATE', color='r', linewidth=2, linestyle='--')
ax2.plot(df_unemployment['MONTH'], df_unemployment['UE_BENEFITS_WEB_SEARCH'], label='SEARCH TREND', color='b', linewidth=2, marker='o')

# Show both legends properly
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Challenge**: Calculate the 3-month or 6-month rolling average for the web searches. Plot the 6-month rolling average search data against the actual unemployment. What do you see in the chart? Which line moves first?

# %%
roll_df = df_unemployment.select_dtypes(include=['number']).rolling(window=6).mean()

# %%
plt.figure(figsize=(14, 8), dpi=120)
plt.title('Unemployment Benefits in the U.S. vs the U/E Rate', fontsize=18)

ax1 = plt.gca()
ax2 = ax1.twinx()


ax1.set_xlabel('Date', fontsize=14)
ax1.set_ylabel('FRED U/E RATE', color='r', fontsize=14)
ax2.set_ylabel('SEARCH TREND', color='b', fontsize=14)

# Tick formatting
ax1.tick_params(axis='y', labelcolor='r', labelsize=14)
ax2.tick_params(axis='y', labelcolor='b', labelsize=14)
ax1.tick_params(axis='x', labelsize=14)

# Date formatting
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

ax1.set_ylim(bottom=3, top=10.5)
ax1.set_xlim([df_unemployment['MONTH'].min(), df_unemployment['MONTH'].max()])

ax1.grid(color='grey', linestyle='--')

# Plotting both lines
ax1.plot(df_unemployment['MONTH'], roll_df['UNRATE'], label='FRED U/E RATE', color='r', linewidth=2, linestyle='--')
ax2.plot(df_unemployment['MONTH'], roll_df['UE_BENEFITS_WEB_SEARCH'], label='SEARCH TREND', color='b', linewidth=2, marker='o')

# Show both legends properly
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Including 2020 in Unemployment Charts

# %% [markdown]
# **Challenge**: Read the data in the 'UE Benefits Search vs UE Rate 2004-20.csv' into a DataFrame. Convert the MONTH column to Pandas Datetime objects and then plot the chart. What do you see?

# %%
df_unemployment = pd.read_csv('Google Trends Data/UE Benefits Search vs UE Rate 2004-20.csv')
df_unemployment['MONTH'] = pd.to_datetime(df_unemployment['MONTH'])
df_unemployment.UE_BENEFITS_WEB_SEARCH.max()
# Out:
# 100

# %%
plt.figure(figsize=(14, 8), dpi=120)
plt.title('Unemployment Benefits in the U.S. vs the U/E Rate', fontsize=18)

ax1 = plt.gca()
ax2 = ax1.twinx()


# Labeling axes
ax1.set_xlabel('Date', fontsize=14)
ax1.set_ylabel('FRED U/E RATE', color='r', fontsize=14)
ax2.set_ylabel('SEARCH TREND', color='b', fontsize=14)

# Tick formatting
ax1.tick_params(axis='y', labelcolor='r', labelsize=14)
ax2.tick_params(axis='y', labelcolor='b', labelsize=14)
ax1.tick_params(axis='x', labelsize=14)

# Date formatting
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(months)

ax1.set_ylim(df_unemployment.UNRATE.min(), df_unemployment.UNRATE.max())
ax1.set_xlim([df_unemployment['MONTH'].min(), df_unemployment['MONTH'].max()])

ax1.grid(color='grey', linestyle='--')

# Plotting both lines
ax1.plot(df_unemployment['MONTH'], df_unemployment ['UNRATE'], label='FRED U/E RATE', color='r', linewidth=2, linestyle='--')
ax2.plot(df_unemployment['MONTH'], df_unemployment ['UE_BENEFITS_WEB_SEARCH'], label='SEARCH TREND', color='b', linewidth=2, marker='o')

# Show both legends properly
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()
